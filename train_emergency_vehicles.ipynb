# %%
import torch
import torchvision
import numpy as np
from torchvision import transforms
import matplotlib.pyplot as plt
import torchvision.models as models
from tqdm import tqdm
import torch.nn as nn
import cv2
from sklearn.model_selection import train_test_split

# %%
SEED = 1

# Use GPU if available, otherwise CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
print('Current Device:', device)
# Out:
# Current Device: mps

# %% [markdown]
# ### Load Dataset

# %%
# Show first image
image = cv2.imread('./datasets/emergency_vehicles/labelled/emergency/1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print(image.shape)
plt.axis('off')
plt.imshow(image)
plt.show()
# Out:
# (224, 224, 3)

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=20),
    transforms.ColorJitter(brightness=0.3, hue=0.05, saturation=0.3),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(size=224)
])

# %%
TRAIN_SIZE = 0.7

dataset = torchvision.datasets.ImageFolder('datasets/emergency_vehicles/labelled', transform)

train_idx, val_idx = train_test_split(np.arange(len(dataset)),
                                           train_size=TRAIN_SIZE, 
                                           random_state=SEED, 
                                           stratify=dataset.targets)

train_data = torch.utils.data.Subset(dataset, train_idx)
val_data = torch.utils.data.Subset(dataset, val_idx)

print('Dataset Size:', len(dataset))
print('Train Data Size:', len(train_data))
print('Validation Data Size:', len(val_data))
# Out:
# Dataset Size: 1646
# Train Data Size: 1152
# Validation Data Size: 494

# %%
# Some quick sanity checks
for img, label in dataset:
    plt.axis('off')
    plt.imshow(img.permute(1,2,0))
    plt.show()
    print('Label: {}'.format(label)) # Emergency vehicles have label 0; non-emergency have label 1
    break
# Out:
# Label: 0

# %%
# Create dataloaders
BATCH_SIZE = 50

train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ### Train Model

# %%
# Note that emergency vehicles have label 0, and non-emergency vehicles have label 1
n_data = len(dataset)
n_notemergency = sum(label for label in dataset.targets)
n_emergency = n_data - n_notemergency
print('Emergency Vehicle Images:', n_emergency)
print('Not Emergency Vehicle Images:', n_notemergency)

# %%
from mylibs.model import Resnet18, CNNClassifier

class_weights = torch.tensor([n_data/n_emergency, n_data/n_notemergency])

model = CNNClassifier(num_classes=2)
lr = 0.008
criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
def train(model, data_loader, criterion, optimizer):
    model.train()
    model.to(device)

    running_loss = 0.
    running_steps = 0
    n_correct = 0
    n_total = 0

    with tqdm(data_loader, desc ="   train") as train_tqdm:
        for inputs, targets in train_tqdm:
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_steps += 1

            _, pred = torch.max(outputs, 1)
            n_correct += (pred==targets).sum().item()
            n_total += len(targets)

            average_train_loss = running_loss / running_steps
            accuracy = n_correct / n_total * 100.

            train_tqdm.set_postfix(loss=average_train_loss, accuracy=accuracy)

    return average_train_loss, accuracy

# %%
@torch.no_grad()
def test(model, data_loader, criterion, optimizer):
    model.eval()
    model.to(device)

    running_loss = 0.
    running_steps = 0
    n_correct = 0
    n_total = 0

    with tqdm(data_loader, desc ="   test") as test_tqdm:
        for inputs, targets in test_tqdm:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)

            loss = criterion(outputs, targets)
            running_loss += loss.item()
            running_steps += 1

            _, pred = torch.max(outputs, 1)
            n_correct += (pred==targets).sum().item()
            n_total += len(targets)
    
        average_test_loss = running_loss / running_steps
        accuracy = n_correct / n_total * 100.

        test_tqdm.set_postfix(loss=average_test_loss, accuracy=accuracy)

    return average_test_loss, accuracy

# %%
for i in range(100):
    train_avg_loss, train_accuracy = train(model, train_loader, criterion, optimizer)
    if (i+1)%10 == 0:
        val_avg_loss, val_accuracy = test(model, val_loader, criterion, optimizer)
        print('Epoch: {:3d}, Train Average Loss: {:.2f}, Train Accuracy: {:.1f}%, Validation Average Loss: {:.2f}, Validation Accuracy: {:.1f}%'\
              .format(i+1, train_avg_loss, train_accuracy, val_avg_loss, val_accuracy))
# Out:
#    train: 100%|██████████| 24/24 [00:29<00:00,  1.24s/it, accuracy=50.7, loss=1.26]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=54.1, loss=0.782]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=54.8, loss=0.727]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=54.2, loss=0.731]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=57.2, loss=0.741]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=55, loss=0.723]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=55.6, loss=0.73]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=55.9, loss=0.752]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=63.5, loss=0.702]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=55.8, loss=0.795]
#    test: 100%|██████████| 10/10 [00:05<00:00,  1.92it/s]
# Epoch:  10, Train Average Loss: 0.80, Train Accuracy: 55.8%, Validation Average Loss: 0.72, Validation Accuracy: 47.8%
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=52.8, loss=0.797]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.31it/s, accuracy=58.2, loss=0.685]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=54.7, loss=0.677]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.30it/s, accuracy=58.6, loss=0.687]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=55, loss=0.716]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.41it/s, accuracy=51.9, loss=0.709]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.43it/s, accuracy=58.2, loss=0.674]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=58.2, loss=0.709]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=58.6, loss=0.69]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=58, loss=0.689]
#    test: 100%|██████████| 10/10 [00:04<00:00,  2.02it/s]
# Epoch:  20, Train Average Loss: 0.69, Train Accuracy: 58.0%, Validation Average Loss: 0.68, Validation Accuracy: 58.7%
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=58.6, loss=0.664]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.43it/s, accuracy=58.7, loss=0.667]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.42it/s, accuracy=58.7, loss=0.667]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.42it/s, accuracy=58.6, loss=0.685]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.33it/s, accuracy=58.6, loss=0.654]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=58.7, loss=0.638]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=58.5, loss=0.685]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.30it/s, accuracy=58.9, loss=0.698]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=58.6, loss=0.647]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=58.6, loss=0.658]
#    test: 100%|██████████| 10/10 [00:05<00:00,  1.91it/s]
# Epoch:  30, Train Average Loss: 0.66, Train Accuracy: 58.6%, Validation Average Loss: 0.72, Validation Accuracy: 54.7%
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=62.7, loss=0.637]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.37it/s, accuracy=63.4, loss=0.667]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.42it/s, accuracy=65.6, loss=0.626]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=66.4, loss=0.627]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=66.9, loss=0.606]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=68.9, loss=0.633]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=70.1, loss=0.63]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=71.9, loss=0.549]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.28it/s, accuracy=73.3, loss=0.536]
#    train: 100%|██████████| 24/24 [00:19<00:00,  1.23it/s, accuracy=74.8, loss=0.531]
#    test: 100%|██████████| 10/10 [00:05<00:00,  1.88it/s]
# Epoch:  40, Train Average Loss: 0.53, Train Accuracy: 74.8%, Validation Average Loss: 0.60, Validation Accuracy: 66.6%
#    train: 100%|██████████| 24/24 [00:19<00:00,  1.24it/s, accuracy=78.8, loss=0.504]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.29it/s, accuracy=71.5, loss=0.606]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=77.5, loss=0.503]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=81.6, loss=0.434]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.37it/s, accuracy=70.3, loss=0.621]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.31it/s, accuracy=74.2, loss=0.544]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=76.9, loss=0.481]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=79.9, loss=0.506]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.35it/s, accuracy=81, loss=0.434]
#    train: 100%|██████████| 24/24 [00:19<00:00,  1.24it/s, accuracy=82.6, loss=0.376]
#    test: 100%|██████████| 10/10 [00:05<00:00,  1.84it/s]
# Epoch:  50, Train Average Loss: 0.38, Train Accuracy: 82.6%, Validation Average Loss: 0.93, Validation Accuracy: 65.0%
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.29it/s, accuracy=81.3, loss=0.411]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.28it/s, accuracy=82.4, loss=0.405]
#    train: 100%|██████████| 24/24 [00:19<00:00,  1.25it/s, accuracy=82.6, loss=0.378]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.27it/s, accuracy=86, loss=0.333]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.27it/s, accuracy=85.5, loss=0.347]
#    train: 100%|██████████| 24/24 [00:19<00:00,  1.26it/s, accuracy=85.5, loss=0.337]
#    train: 100%|██████████| 24/24 [00:19<00:00,  1.25it/s, accuracy=84.9, loss=0.351]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.29it/s, accuracy=77.7, loss=0.504]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.29it/s, accuracy=84.6, loss=0.364]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.29it/s, accuracy=85.2, loss=0.338]
#    test: 100%|██████████| 10/10 [00:05<00:00,  1.81it/s]
# Epoch:  60, Train Average Loss: 0.34, Train Accuracy: 85.2%, Validation Average Loss: 0.81, Validation Accuracy: 68.8%
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.28it/s, accuracy=78.8, loss=0.453]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.30it/s, accuracy=85.1, loss=0.354]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.27it/s, accuracy=86.2, loss=0.345]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.30it/s, accuracy=84.6, loss=0.404]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=78.4, loss=0.451]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.33it/s, accuracy=84.9, loss=0.341]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.37it/s, accuracy=86.6, loss=0.341]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.42it/s, accuracy=75.3, loss=0.515]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.43it/s, accuracy=86.3, loss=0.335]
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.44it/s, accuracy=82.8, loss=0.38]
#    test: 100%|██████████| 10/10 [00:04<00:00,  2.05it/s]
# Epoch:  70, Train Average Loss: 0.38, Train Accuracy: 82.8%, Validation Average Loss: 0.67, Validation Accuracy: 65.0%
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.41it/s, accuracy=85.6, loss=0.396]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=81.1, loss=0.414]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.35it/s, accuracy=85.2, loss=0.356]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=86, loss=0.33]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.37it/s, accuracy=86.5, loss=0.357]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=86, loss=0.314]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=86, loss=0.318]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=87, loss=0.303]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=88.6, loss=0.264]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.34it/s, accuracy=88.4, loss=0.292]
#    test: 100%|██████████| 10/10 [00:04<00:00,  2.02it/s]
# Epoch:  80, Train Average Loss: 0.29, Train Accuracy: 88.4%, Validation Average Loss: 0.99, Validation Accuracy: 61.9%
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=80.2, loss=0.45]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.37it/s, accuracy=86.2, loss=0.34]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=87, loss=0.329]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=84.7, loss=0.403]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=86.7, loss=0.304]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.41it/s, accuracy=88.6, loss=0.277]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=90.5, loss=0.24]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.36it/s, accuracy=89.2, loss=0.244]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=89.2, loss=0.246]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=90.4, loss=0.231]
#    test: 100%|██████████| 10/10 [00:04<00:00,  2.06it/s]
# Epoch:  90, Train Average Loss: 0.23, Train Accuracy: 90.4%, Validation Average Loss: 0.35, Validation Accuracy: 84.4%
#    train: 100%|██████████| 24/24 [00:16<00:00,  1.42it/s, accuracy=88.7, loss=0.248]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=89.1, loss=0.235]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.32it/s, accuracy=90.5, loss=0.277]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.41it/s, accuracy=87.4, loss=0.297]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=89.8, loss=0.278]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.34it/s, accuracy=88.5, loss=0.317]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s, accuracy=86.4, loss=0.392]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.39it/s, accuracy=87, loss=0.315]
#    train: 100%|██████████| 24/24 [00:17<00:00,  1.40it/s, accuracy=85.8, loss=0.314]
#    train: 100%|██████████| 24/24 [00:18<00:00,  1.33it/s, accuracy=89, loss=0.292]
#    test: 100%|██████████| 10/10 [00:04<00:00,  2.04it/s]
# Epoch: 100, Train Average Loss: 0.29, Train Accuracy: 89.0%, Validation Average Loss: 0.38, Validation Accuracy: 84.4%

# %%
val_avg_loss, val_accuracy = test(model, val_loader, criterion, optimizer)
print('Validation Average Loss: {:.2f}, Validation Accuracy: {:.1f}%'\
             .format(val_avg_loss, val_accuracy))
# Out:
#    test: 100%|██████████| 10/10 [00:05<00:00,  1.81it/s]
# Validation Average Loss: 0.40, Validation Accuracy: 83.4%

# %% [markdown]
# ### Save Model Parameters

# %%
torch.save(model.state_dict(), './models/emergency_vehicles.pth')
